# %%
import requests

# %%
r = requests.get('https://services7.arcgis.com/mOBPykOjAyBO2ZKk/arcgis/rest/services/RKI_COVID19/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')
d = r.json()

# %%
d
# Out:
# {'objectIdFieldName': 'ObjectId',
#  'uniqueIdField': {'name': 'ObjectId', 'isSystemMaintained': True},
#  'globalIdFieldName': '',
#  'fields': [{'name': 'IdBundesland',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'IdBundesland',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Bundesland',
#    'type': 'esriFieldTypeString',
#    'alias': 'Bundesland',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 2147483647,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Landkreis',
#    'type': 'esriFieldTypeString',
#    'alias': 'Landkreis',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 2147483647,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Altersgruppe',
#    'type': 'esriFieldTypeString',
#    'alias': 'Altersgruppe',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 2147483647,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Geschlecht',
#    'type': 'esriFieldTypeString',
#    'alias': 'Geschlecht',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 2147483647,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'AnzahlFall',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'AnzahlFall',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'AnzahlTodesfall',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'AnzahlTodesfall',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'ObjectId',
#    'type': 'esriFieldTypeOID',
#    'alias': 'ObjectId',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Meldedatum',
#    'type': 'esriFieldTypeDate',
#    'alias': 'Meldedatum',
#    'sqlType': 'sqlTypeOther',
#    'length': 0,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'IdLandkreis',
#    'type': 'esriFieldTypeString',
#    'alias': 'Landkreis ID',
#    'sqlType': 'sqlTypeOther',
#    'length': 256,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Datenstand',
#    'type': 'esriFieldTypeString',
#    'alias': 'Datenstand',
#    'sqlType': 'sqlTypeOther',
#    'length': 256,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'NeuerFall',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'Neuer Fall',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'NeuerTodesfall',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'Neuer Todesfall',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None}],
#  'exceededTransferLimit': True,
#  'features': [{'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810232,
#     'Meldedatum': 1584144000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810233,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810234,
#     'Meldedatum': 1584748800000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810235,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810236,
#     'Meldedatum': 1585958400000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810237,
#     'Meldedatum': 1584144000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810238,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810239,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810240,
#     'Meldedatum': 1584144000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810241,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810242,
#     'Meldedatum': 1584144000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810243,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810244,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810245,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810246,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810247,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 1,
#     'ObjectId': 810248,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': 0}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810249,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810250,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810251,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810252,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Flensburg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810253,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01001',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810254,
#     'Meldedatum': 1583798400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810255,
#     'Meldedatum': 1583884800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810256,
#     'Meldedatum': 1584057600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810257,
#     'Meldedatum': 1584144000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810258,
#     'Meldedatum': 1584316800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810259,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810260,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810261,
#     'Meldedatum': 1584748800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810262,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810263,
#     'Meldedatum': 1585094400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810264,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810265,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810266,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810267,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810268,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810269,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810270,
#     'Meldedatum': 1585958400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810271,
#     'Meldedatum': 1586044800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810272,
#     'Meldedatum': 1583798400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810273,
#     'Meldedatum': 1583971200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810274,
#     'Meldedatum': 1584316800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810275,
#     'Meldedatum': 1584403200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810276,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810277,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810278,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810279,
#     'Meldedatum': 1584835200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810280,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810281,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810282,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810283,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810284,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810285,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810286,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810287,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810288,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810289,
#     'Meldedatum': 1585958400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810290,
#     'Meldedatum': 1586044800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810291,
#     'Meldedatum': 1583884800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810292,
#     'Meldedatum': 1583971200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810293,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810294,
#     'Meldedatum': 1584748800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810295,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810296,
#     'Meldedatum': 1585094400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810297,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810298,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810299,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810300,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810301,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810302,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810303,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810304,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810305,
#     'Meldedatum': 1586044800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810306,
#     'Meldedatum': 1583798400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810307,
#     'Meldedatum': 1583884800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810308,
#     'Meldedatum': 1583971200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810309,
#     'Meldedatum': 1584316800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810310,
#     'Meldedatum': 1584403200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810311,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810312,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810313,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810314,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810315,
#     'Meldedatum': 1585094400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810316,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810317,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810318,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810319,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810320,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810321,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810322,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810323,
#     'Meldedatum': 1585958400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810324,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810325,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810326,
#     'Meldedatum': 1584835200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 1,
#     'ObjectId': 810327,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': 0}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810328,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810329,
#     'Meldedatum': 1585094400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810330,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810331,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810332,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810333,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810334,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810335,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810336,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810337,
#     'Meldedatum': 1585872000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810338,
#     'Meldedatum': 1586044800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810339,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810340,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810341,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810342,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810343,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810344,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810345,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810346,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810347,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810348,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810349,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'SK Kiel',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 810350,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01002',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
# ...
#     'Meldedatum': 1584144000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811191,
#     'Meldedatum': 1584230400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811192,
#     'Meldedatum': 1584316800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811193,
#     'Meldedatum': 1584403200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811194,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811195,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811196,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811197,
#     'Meldedatum': 1584748800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811198,
#     'Meldedatum': 1584835200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811199,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811200,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811201,
#     'Meldedatum': 1585094400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811202,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811203,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811204,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811205,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811206,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811207,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811208,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811209,
#     'Meldedatum': 1585958400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811210,
#     'Meldedatum': 1585958400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811211,
#     'Meldedatum': 1583107200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811212,
#     'Meldedatum': 1584057600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811213,
#     'Meldedatum': 1584316800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811214,
#     'Meldedatum': 1584403200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811215,
#     'Meldedatum': 1584489600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811216,
#     'Meldedatum': 1584576000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811217,
#     'Meldedatum': 1584662400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811218,
#     'Meldedatum': 1584748800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811219,
#     'Meldedatum': 1584921600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811220,
#     'Meldedatum': 1585008000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811221,
#     'Meldedatum': 1585094400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811222,
#     'Meldedatum': 1585180800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811223,
#     'Meldedatum': 1585267200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811224,
#     'Meldedatum': 1585353600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811225,
#     'Meldedatum': 1585440000000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811226,
#     'Meldedatum': 1585526400000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811227,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811228,
#     'Meldedatum': 1585612800000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811229,
#     'Meldedatum': 1585699200000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811230,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 0,
#     'NeuerTodesfall': -9}},
#   {'attributes': {'IdBundesland': 1,
#     'Bundesland': 'Schleswig-Holstein',
#     'Landkreis': 'LK Stormarn',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 811231,
#     'Meldedatum': 1585785600000,
#     'IdLandkreis': '01062',
#     'Datenstand': '06.04.2020, 00:00 Uhr',
#     'NeuerFall': 1,
#     'NeuerTodesfall': -9}},
#   ...]}
